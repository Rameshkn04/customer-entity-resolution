# %% [markdown]
# Install Dependencies

# %%
pip install pandas rapidfuzz numpy
# Out:
# Requirement already satisfied: pandas in c:\users\rames\desktop\customer_entity_resolution\.venv\lib\site-packages (3.0.0)
# Requirement already satisfied: rapidfuzz in c:\users\rames\desktop\customer_entity_resolution\.venv\lib\site-packages (3.14.3)
# Requirement already satisfied: numpy in c:\users\rames\desktop\customer_entity_resolution\.venv\lib\site-packages (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rames\desktop\customer_entity_resolution\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\rames\desktop\customer_entity_resolution\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\rames\desktop\customer_entity_resolution\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Step 1: Load Data

# %%
import pandas as pd
import numpy as np
from rapidfuzz import fuzz
from rapidfuzz.distance import JaroWinkler


df = pd.read_csv("data/customers.csv")
df.fillna("", inplace=True)
df.head()
# Out:
#    customer_id          name               email       phone    address
# 0            1    Ramesh K N    ramesh@gmail.com  9876543210  Bangalore
# 1            2     Ramesh KN    ramesh@gmail.com  9876543210  Bengaluru
# 2            3  Ramesh Kumar  ramesh.k@gmail.com  9876543211  Bangalore
# 3            4  Suresh Kumar    suresh@gmail.com  9123456780     Mysore
# 4            5     Ramesh K.    ramesh@gmail.com  9876543210  Bengaluru

# %%
def normalize(text):
    return str(text).lower().strip()

for col in ["name", "email", "address"]:
    df[col] = df[col].apply(normalize)

# %% [markdown]
# Step 2: Blocking Strategy (Scalability)

# %% [markdown]
# We reduce comparisons by blocking on first letter of name + email domain.

# %%
def create_block_key(row):
    name_key = row['name'][:1].lower()
    email_key = row['email'].split('@')[-1] if '@' in row['email'] else ''
    return name_key + "_" + email_key

df["block_key"] = df.apply(create_block_key, axis=1)
df.head()
# Out:
#    customer_id          name               email       phone    address  \
# 0            1    ramesh k n    ramesh@gmail.com  9876543210  bangalore
# 1            2     ramesh kn    ramesh@gmail.com  9876543210  bengaluru
# 2            3  ramesh kumar  ramesh.k@gmail.com  9876543211  bangalore
# 3            4  suresh kumar    suresh@gmail.com  9123456780     mysore
# 4            5     ramesh k.    ramesh@gmail.com  9876543210  bengaluru
#
#      block_key
# 0  r_gmail.com
# 1  r_gmail.com
# 2  r_gmail.com
# 3  s_gmail.com
# 4  r_gmail.com

# %% [markdown]
# This reduces O(n²) comparisons drastically.

# %% [markdown]
# Step 3: Fuzzy Matching (RapidFuzz)
#
# We combine multiple fields:
#
# Name similarity
#
# Email similarity
#
# Phone exact match (strong signal)

# %%
def compute_similarity(r1, r2):
    name_lev = fuzz.token_sort_ratio(r1['name'], r2['name'])
    name_jw = JaroWinkler.similarity(r1['name'], r2['name']) * 100
    email_score = fuzz.ratio(r1['email'], r2['email'])
    phone_score = 100 if r1['phone'] == r2['phone'] else 0

    final_score = (
        0.4 * name_lev +
        0.2 * name_jw +
        0.25 * email_score +
        0.15 * phone_score
    )
    return final_score

# %% [markdown]
# Step 4: Find Duplicate Pairs (Inside Blocks)

# %%
matches = []
THRESHOLD = 85

for _, block in df.groupby("block_key"):
    records = block.to_dict("records")
    for i in range(len(records)):
        for j in range(i+1, len(records)):
            score = compute_similarity(records[i], records[j])
            if score >= THRESHOLD:
                matches.append({
                    "id1": records[i]["customer_id"],
                    "id2": records[j]["customer_id"],
                    "score": score
                })

matches_df = pd.DataFrame(matches)
matches_df
# Out:
#    id1  id2      score
# 0    8    9  85.833333
# 1   16   17  89.269231
# 2   18   19  88.400000
# 3   14   15  87.519139
# 4    1    2  97.494737
# 5    1    5  92.439766
# 6    2    5  94.666667
# 7    3    6  96.351648
# 8   11   12  89.656566
# 9    4    7  90.666667

# %% [markdown]
# Conflict Resolution & Merge Logic
# Rules Used (Explain in Interview)
#
# ✔ Prefer non-null values
#
# ✔ Prefer longer strings (more complete info)
#
# ✔ Keep earliest customer_id as master

# %%
def merge_records(group):
    merged = {}
    for col in group.columns:
        if col == "customer_id":
            merged[col] = group[col].min()
        else:
            values = group[col].astype(str).unique()
            merged[col] = max(values, key=len)
    return pd.Series(merged)

# %% [markdown]
# Apply Merging

# %%
duplicate_ids = set(matches_df['id2'])

unique_df = df[~df['customer_id'].isin(duplicate_ids)]


merged_df = (
    df[df["customer_id"].isin(duplicate_ids)]
    .groupby("block_key")
    .apply(merge_records)
    .reset_index(drop=True)   
)


final_df = pd.concat([unique_df, merged_df], ignore_index=True)
final_df["block_key"] = final_df.apply(create_block_key, axis=1)
final_df
# Out:
#     customer_id              name               email       phone    address  \
# 0             1        ramesh k n    ramesh@gmail.com  9876543210  bangalore
# 1             3      ramesh kumar  ramesh.k@gmail.com  9876543211  bangalore
# 2             4      suresh kumar    suresh@gmail.com  9123456780     mysore
# 3             8      anita sharma     anita@gmail.com  9988776655      delhi
# 4            10      anita sharma   anita.s@gmail.com  9988776656      delhi
# 5            11       rohit verma     rohit@gmail.com  8899776655     mumbai
# 6            13       rohit verma   rohit.v@gmail.com  8899776656     mumbai
# 7            14       pooja patel     pooja@gmail.com  7766554433  ahmedabad
# 8            16        amit singh      amit@gmail.com  6655443322     jaipur
# 9            18        neha joshi      neha@gmail.com  5544332211       pune
# 10           20       arjun mehta     arjun@gmail.com  4433221100     indore
# 11            9  amit kumar singh     anita@gmail.com  9988776655  new delhi
# 12           19            neha j      neha@gmail.com  5544332211       pune
# 13           15          pooja p.     pooja@gmail.com  7766554433  ahemdabad
# 14            2    ramesh kumar n  ramesh.k@gmail.com  9876543210  bengaluru
# 15            7          suresh k    suresh@gmail.com  9123456780     mysuru
#
#       block_key
# 0   r_gmail.com
# 1   r_gmail.com
# 2   s_gmail.com
# 3   a_gmail.com
# 4   a_gmail.com
# 5   r_gmail.com
# 6   r_gmail.com
# 7   p_gmail.com
# 8   a_gmail.com
# 9   n_gmail.com
# 10  a_gmail.com
# 11  a_gmail.com
# 12  n_gmail.com
# 13  p_gmail.com
# 14  r_gmail.com
# 15  s_gmail.com

# %% [markdown]
# Evaluation Metrics (Must Include)

# %%
print("Total Records:", len(df))
print("Duplicate Pairs Found:", len(matches_df))
print("Final Unique Records:", len(final_df))
# Out:
# Total Records: 20
# Duplicate Pairs Found: 10
# Final Unique Records: 16

# %% [markdown]
# Shows impact of entity resolution clearly.

# %% [markdown]
# Output (Merged Clean Data)

# %%
final_df.to_csv("merged_customers.csv", index=False)

# %% [markdown]
# ## Match Summary Report
#
# - Total input records processed
# - Duplicate pairs detected using fuzzy matching
# - Final unique customer records after merge
#
# ### Matching Techniques
# - Levenshtein distance (token-based similarity)
# - Jaro-Winkler similarity for name comparison
# - Blocking using name prefix and email domain
#
# ### Conflict Resolution Strategy
# - Lowest customer_id retained as master record
# - Non-null and longer values prioritized
# - Deterministic merge logic
#
# ### Scalability
# - Blocking significantly reduces pairwise comparisons
# - Suitable for large customer datasets
